# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import ray
# Out:
# 2024-05-01 23:58:20,534	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %%
df = pd.read_csv("../datasets/mpst_full_data.csv")
df.head()
# Out:
#      imdb_id                                          title  \
# 0  tt0057603                        I tre volti della paura
# 1  tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2  tt0033045                     The Shop Around the Corner
# 3  tt0113862                             Mr. Holland's Opus
# 4  tt0086250                                       Scarface
#
#                                        plot_synopsis  \
# 0  Note: this synopsis is for the orginal Italian...
# 1  Two thousand years ago, Nhagruul the Foul, a s...
# 2  Matuschek's, a gift store in Budapest, is the ...
# 3  Glenn Holland, not a morning person by anyone'...
# 4  In May 1980, a Cuban man named Tony Montana (A...
#
#                                                 tags  split synopsis_source
# 0          cult, horror, gothic, murder, atmospheric  train            imdb
# 1                                           violence  train            imdb
# ...

# %%
ray_df = ray.data.from_pandas(df)
batch = ray_df.take_batch(batch_size=10, batch_format='pandas')
batch
# Out:
# 2024-05-01 23:58:21,360	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-05-01 23:58:23,287	INFO worker.py:1740 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2024-05-01 23:58:25,091	INFO streaming_executor.py:112 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-01_23-58-21_380708_2791196/logs/ray-data
# 2024-05-01 23:58:25,092	INFO streaming_executor.py:113 -- Execution plan of Dataset: InputDataBuffer[Input] -> LimitOperator[limit=10]
# [dataset]: Run `pip install tqdm` to enable progress reporting.
#      imdb_id                                          title  \
# 0  tt0057603                        I tre volti della paura
# 1  tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2  tt0033045                     The Shop Around the Corner
# 3  tt0113862                             Mr. Holland's Opus
# ...

# %%
print(ray_df.count)
# Out:
# <bound method Dataset.count of MaterializedDataset(
#    num_blocks=1,
#    num_rows=14828,
#    schema={
#       imdb_id: object,
#       title: object,
#       plot_synopsis: object,
#       tags: object,
#       split: object,
#       synopsis_source: object
#    }
# )>

# %%
# Out:
# 2024-05-02 00:05:54,096	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::process_row() (pid=2791486, ip=192.168.0.113)
#   File "/tmp/ipykernel_2791196/4241195262.py", line 3, in process_row
# TypeError: tuple indices must be integers or slices, not str
# 2024-05-02 00:05:54,099	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::process_row() (pid=2791483, ip=192.168.0.113)
#   File "/tmp/ipykernel_2791196/4241195262.py", line 3, in process_row
# TypeError: tuple indices must be integers or slices, not str
# 2024-05-02 00:05:54,100	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::process_row() (pid=2791486, ip=192.168.0.113)
#   File "/tmp/ipykernel_2791196/4241195262.py", line 3, in process_row
# TypeError: tuple indices must be integers or slices, not str
# ...
